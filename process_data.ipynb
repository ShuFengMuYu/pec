# %% [markdown]
# # 处理数据
# 原本的CpedDataset需要每次重新处理数据，事先进行处理并保存结果可以节省时间

# %%
import logging
logger = logging.getLogger('cped.data')
logger.setLevel(level=logging.INFO)

# %% [markdown]
# ## 设置tokenizer
# 需要根据分词结果来为每个token嵌入信息

# %%
# T5仅仅是作为样例
from transformers import BertTokenizer, MT5ForConditionalGeneration, Text2TextGenerationPipeline
tokenizer:BertTokenizer = BertTokenizer.from_pretrained("t5/t5-v1_1-small-chinese-cluecorpussmall")
# model = MT5ForConditionalGeneration.from_pretrained("t5/t5-v1_1-small-chinese-cluecorpussmall")

# %%
from utils.cped_dataset import cped_get_data_from_dir, CpedDataset

data_path = '../data/CPED'
cache_path = './cache/cped_cache'

cped_filenames = {"train":"train_split.csv", 
                  "valid":"valid_split.csv", 
                  "test":"test_split.csv"}
data, sample = cped_get_data_from_dir(dir_path=data_path, 
                                      cache_path=cache_path,
                                      tokenizer=tokenizer,
                                      logger=logger, 
                                      filenames=cped_filenames)

logger.info("读取CPED数据集")
train_data = data["train"]
valid_data = data["valid"]
train_dataset = CpedDataset(data=train_data, 
                            tokenizer=tokenizer, 
                            emotion_type='Emotion',
                            da_type='DA', 
                            persona_type=["Gender","Neuroticism","Extraversion","Openness","Agreeableness","Conscientiousness", "Age"],
                            max_history=25,
                            batch_first=True, 
                            lm_labels=True, 
                            with_current_speaker=True,
                            with_current_persona=True,
                            with_current_emotion=True,
                            with_current_da=True,
                            with_emotion=True, 
                            with_da=False,
                            use_speaker_name_as_speaker_list=False,
                            set_eda_in_speaker=False,
                            set_current_speaker_mask=False)


valid_dataset = CpedDataset(data=valid_data, 
                            tokenizer=tokenizer, 
                            emotion_type='Emotion',
                            da_type='DA', 
                            persona_type=["Gender","Neuroticism","Extraversion","Openness","Agreeableness","Conscientiousness", "Age"],
                            max_history=25,
                            batch_first=True, 
                            lm_labels=True, 
                            with_current_speaker=True,
                            with_current_persona=True,
                            with_current_emotion=True,
                            with_current_da=True,
                            with_emotion=True, 
                            with_da=False,
                            use_speaker_name_as_speaker_list=False,
                            set_eda_in_speaker=False,
                            set_current_speaker_mask=False)

test_data = data["test"]
test_dataset = CpedDataset(data=test_data, 
                            tokenizer=tokenizer, 
                            emotion_type='Emotion',
                            da_type='DA', 
                            persona_type=["Gender","Neuroticism","Extraversion","Openness","Agreeableness","Conscientiousness", "Age"],
                            max_history=25,
                            batch_first=True, 
                            lm_labels=True, 
                            with_current_speaker=True,
                            with_current_persona=True,
                            with_current_emotion=True,
                            with_current_da=True,
                            with_emotion=True, 
                            with_da=False,
                            use_speaker_name_as_speaker_list=False,
                            set_eda_in_speaker=False,
                            set_current_speaker_mask=False)

# %%
tokenizer.decode(tokenizer('深度学习真的烦')['input_ids'])
# Out:
# '[CLS] 深 度 学 习 真 的 烦 [SEP]'

# %%
import json
persona_type = ["Gender","Neuroticism","Extraversion","Openness","Agreeableness","Conscientiousness","Age"]

# %%
with open('data/t5/train.jsonl', mode='w', encoding='utf8') as fp:
    dialog = {}
    for i in range(len(train_dataset)):
        dialog['input'] = tokenizer.decode(train_dataset[i]['input_ids'])
        dialog['speaker'] = train_dataset[i]['token_type_ids']
        for persona in persona_type:
            dialog[persona.lower()] = train_dataset[i][persona]
        dialog['emotion'] = train_dataset[i]['emotion_ids']
        fp.write(json.dumps(dialog, ensure_ascii=False) + '\n')

# %%
with open('data/t5/valid.jsonl', mode='w', encoding='utf8') as fp:
    dialog = {}
    for i in range(len(valid_dataset)):
        dialog['input'] = tokenizer.decode(valid_dataset[i]['input_ids'])
        dialog['speaker'] = valid_dataset[i]['token_type_ids']
        for persona in persona_type:
            dialog[persona.lower()] = valid_dataset[i][persona]
        dialog['emotion'] = valid_dataset[i]['emotion_ids']
        fp.write(json.dumps(dialog, ensure_ascii=False) + '\n')

# %%
# 可以用来检查对应关系
# with open('test.csv', mode='w', encoding='gbk') as fp:
#     for i in range(len(test_dataset)):
#         fp.write((','.join(tokenizer.tokenize(tokenizer.decode(test_dataset[i]['input_ids'])))) + '\n')
#         fp.write(','.join(test_dataset[i]['token_type_ids']) + '\n')
#         for persona in persona_type:
#             fp.write(','.join(test_dataset[i][persona]) + '\n')
#         fp.write(','.join(test_dataset[i]['emotion_ids']) + '\n')
with open('data/t5/test.jsonl', mode='w', encoding='utf8') as fp:
    dialog = {}
    for i in range(len(test_dataset)):
        dialog['input'] = tokenizer.decode(test_dataset[i]['input_ids'])
        dialog['speaker'] = test_dataset[i]['token_type_ids']
        for persona in persona_type:
            dialog[persona.lower()] = test_dataset[i][persona]
        dialog['emotion'] = test_dataset[i]['emotion_ids']
        fp.write(json.dumps(dialog, ensure_ascii=False) + '\n')

# %% [markdown]
# ## 验证新的Dataset是否能用

# %%
from pec_dataset import PecDataset

train_pec = PecDataset('data/t5/train.jsonl')
print('train set')
for i in range(3):
    print(train_pec[i])

valid_pec = PecDataset('data/t5/valid.jsonl')
print('valid set')
for i in range(3):
    print(valid_pec[i])

test_pec = PecDataset('data/t5/test.jsonl')
print('test set')
for i in range(3):
    print(test_pec[i])
# Out:
# train set
# {'input': '[CLS] 您 想 去 哪 [SEP] 你 来 这 几 年 了 [SEP] 5 年 [SEP]', 'speaker': ['[CLS]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker2]', '[speaker2]', '[speaker2]'], 'gender': ['[CLS]', 'female', 'female', 'female', 'female', 'female', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'female', 'female', 'female'], 'neuroticism': ['[CLS]', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low'], 'extraversion': ['[CLS]', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high'], 'openness': ['[CLS]', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high'], 'agreeableness': ['[CLS]', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', '
', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]'], 'gender': ['[CLS]', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'fe ...
# test set
# {'input': '[CLS] 要 不 然 怎 么 是 典 藏 版 [SEP] 赶 紧 拿 出 来 给 我 老 姐 看 看 ， 她 不 信 [SEP] 其 实 变 形 金 刚 不 见 了 [SEP] 我 昨 天 晚 上 把 汽 车 放 在 窗 口 [SEP] 让 他 接 受 月 光 的 灵 气 [SEP] 第 二 天 早 上 醒 来 就 不 见 了 [SEP] 月 光 的 灵 气 [SEP] 可 能 是 飞 回 赛 博 坦 星 球 去 了 吧 ！ [SEP]', 'speaker': ['[CLS]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]'], 'gender': ['[CLS]', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female'], 'neuroticism': ['[CLS]', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'high', 'high', 'high', 'high', 'high', 'high', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low'], 'extraversion': ['[CLS]', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'low', 'low', 'low', 'low', 'low', 'low', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high'], 'openness': ['[CLS]', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'hi ...
# {'input': '[CLS] 我 没 生 过 孩 子 [SEP] 不 过 展 博 是 我 带 大 的 [SEP] 虽 然 被 我 坑 了 很 多 次 [SEP] 但 现 在 还 是 顽 强 地 活 着 [SEP] 但 是 我 不 确 定 我 喜 不 喜 欢 孩 子 [SEP] 哎 呀 ！ ， 焦 虑 的 时 候 不 要 做 任 何 判 断 [SEP] 先 解 决 情 绪 问 题 [SEP] 我 焦 虑 那 阵 ， 心 理 医 生 建 议 我 养 宠 物 [SEP] 有 用 吗 ？ [SEP]', 'speaker': ['[CLS]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]'], 'gender': ['[CLS]', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female'], 'neuroticism': ['[CLS]', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'high', 'high', 'high', 'high', 'high'], 'extraversion': ['[CLS]', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'hig ...
# {'input': '[CLS] 对 [SEP] 准 是 他 干 的 [SEP] 他 制 造 悬 案 好 体 现 神 探 的 价 值 [SEP] 我 也 这 么 想 [SEP] 这 小 子 一 个 人 嫌 玩 这 个 游 戏 太 闷 [SEP] 想 把 游 戏 玩 大 了 [SEP] 让 咱 们 都 陪 着 他 玩 [SEP] 他 也 不 想 想 咱 们 这 么 精 明 的 父 母 能 被 他 蒙 了 吗 ？ 我 告 诉 你 现 在 这 饼 铛 肯 定 在 他 床 底 下 藏 着 [SEP]', 'speaker': ['[CLS]', '[speaker1]', '[speaker1]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker1]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]', '[speaker2]'], 'gender': ['[CLS]', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female'], 'neuroticism': ['[CLS]', 'low', 'low', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high'], 'extraversion': ['[CLS]', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high', 'high' ...
